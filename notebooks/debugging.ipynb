# %%
import happyplanets as hp
# Out:
# /Users/nksaunde/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
tf = hp.TransitFitter(target_name='K2-199', n_obs=1)
# Out:
# /Users/nksaunde/anaconda3/lib/python3.6/site-packages/numpy/lib/nanfunctions.py:1172: RuntimeWarning: All-NaN slice encountered
#   overwrite_input, interpolation)
# /Users/nksaunde/anaconda3/lib/python3.6/site-packages/theano/tensor/slinalg.py:255: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number4.476156e-19
#   rval = scipy.linalg.solve(A, b)

# %%
model = tf.test_fit()
# Out:
# optimizing logp for variables: ['t0', 'period_interval__']
# message: Desired error not necessarily achieved due to precision loss.
# logp: 1209.2630432988497 -> 1214.3956165003467
# optimizing logp for variables: ['mean', 'r_pl_interval__', 'r_star']
# message: Desired error not necessarily achieved due to precision loss.
# logp: 1214.3956165003467 -> 1277.0140289502974
# optimizing logp for variables: ['r_star']
# message: Desired error not necessarily achieved due to precision loss.
# logp: 1277.0140289502974 -> 1277.0140289502974
# optimizing logp for variables: ['mean', 't0', 'period_interval__']
# message: Desired error not necessarily achieved due to precision loss.
# logp: 1277.0140289502974 -> 1277.9160043164186
# optimizing logp for variables: ['mean', 'r_pl_interval__', 'r_star']
# message: Optimization terminated successfully.
# logp: 1277.9160043164186 -> 1278.0476063372582
# ...

# %%
tf.full_fit()
# Out:
# ...
# Sampling 4 chains: 100%|██████████| 208/208 [00:05<00:00, 34.90draws/s]
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [logs2, period, r_pl, b, u, t0, m_star, r_star, mean]
# Sampling 4 chains: 100%|██████████| 4000/4000 [00:46<00:00, 85.36draws/s]
# The acceptance probability does not match the target. It is 0.8130500141795544, but should be close to 0.9. Try to increase the number of tuning steps.
# The acceptance probability does not match the target. It is 0.8303462587641721, but should be close to 0.9. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.
# Generating summary for target K2-199.

# %%
import matplotlib.pyplot as plt
plt.plot(tf.lightcurve.flux)

# %%
tf.lightcurve.plot()
