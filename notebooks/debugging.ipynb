# %%
import happyplanets as hp
# Out:
# /Users/nksaunde/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
tf = hp.TransitFitter(target_name='K2-201', n_obs=1)

# %%
tf.lightcurve.scatter()

# %%
model = tf.test_fit()

# %%
tf.full_fit()

# %%
mask = tf.system.create_planet_mask(tf.lightcurve.time, n_dur_mask=2)

# %%
ax = tf.lightcurve[mask].scatter(normalize=False, c='r')
tf.lightcurve[~mask].scatter(normalize=False, ax=ax)

# %%
len(tf.lightcurve[~mask].flux)

# %%
tf.system.planets[1].duration

# %%
tf.system.planets[1].pl_period

# %%
from happyplanets.planetsystem import create_planet_system
system = create_planet_system('K2-201')
ts = hp.TimeSeries(target_name='K2-201', system=system)

# %%
lc = ts.return_lightcurve()
# Out:
# /Users/nksaunde/anaconda3/lib/python3.6/site-packages/theano/tensor/slinalg.py:255: LinAlgWarning: scipy.linalg.solve
# Ill-conditioned matrix detected. Result is not guaranteed to be accurate.
# Reciprocal condition number7.508370e-20
#   rval = scipy.linalg.solve(A, b)

# %%
mask = system.create_planet_mask(lc.time, n_dur_mask=3)

# %%
ax = lc[~mask].scatter(normalize=False)
lc[mask].scatter(ax=ax, c='r', normalize=False)

# %%
ax = ts.corrector.plot_diagnostics()

# %%
lc.scatter(ax=ax)

# %%
lc[mask].flux

# %%
lc[~mask].flux

# %%
ax=lc[:250].scatter(normalize=False)
lc[:250][mask[:250]].scatter(ax=ax, c='r', normalize=False)

# %%
mask

# %%
lc.scatter(normalize=False)

# %%
system.planets[0].pl_period
# Out:
# <Quantity 1.05979 d>
