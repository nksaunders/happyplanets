# %%
import numpy as np
import pandas as pd
import lightkurve as lk
import matplotlib.pyplot as plt
from lightkurve import MPLSTYLE

# %%
sr = lk.search_targetpixelfile('pi men')

# %%
sr
# Out:
# SearchResult containing 3 data products.
#
# target_name                     productFilename                        description     distance
# ----------- ------------------------------------------------------- ------------------ --------
#   261136679 tess2018206045859-s0001-0000000261136679-0120-s_tp.fits Target pixel files      0.0
#   261136679 tess2018292075959-s0004-0000000261136679-0124-s_tp.fits Target pixel files      0.0
#   261136679 tess2019032160000-s0008-0000000261136679-0136-s_tp.fits Target pixel files      0.0

# %%
tpfc = sr.download_all()

# %%
lc = tpfc[0].to_lightcurve(aperture_mask='pipeline')

# %%
lc.scatter()

# %%
for t in tpfc[1:]:
    flc = flc.append(t.to_lightcurve(aperture_mask='pipeline'))

# %%
flc.scatter()
